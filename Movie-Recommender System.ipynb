# %%
import pandas as pd
import numpy as np

# %%
movie=pd.read_csv("tmdb_5000_movies.csv")

# %%
credit=pd.read_csv("tmdb_5000_credits.csv")

# %%
movie.head(1)
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                       homepage     id  \
# 0  http://www.avatarmovie.com/  19995
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
#
#   original_title                                           overview  \
# 0         Avatar  In the 22nd century, a paraplegic Marine is di...
#
#    popularity                               production_companies  \
# 0  150.437577  [{"name": "Ingenious Film Partners", "id": 289...
#
#                                 production_countries release_date     revenue  \
# 0  [{"iso_3166_1": "US", "name": "United States o...   2009-12-10  2787965087
#
#    runtime                                   spoken_languages    status  \
# 0    162.0  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
#
# ...

# %%
# merging movie with credit kyuki dono m same hi movie k describe kr rahe h
movie.merge(credit,on="title")
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4804     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4805       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4806          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4807          0                                                 []
# 4808          0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# ...

# %%
movies=movie.merge(credit,on="title")

# %%
movies.head(1)
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                       homepage     id  \
# 0  http://www.avatarmovie.com/  19995
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
#
#   original_title                                           overview  \
# 0         Avatar  In the 22nd century, a paraplegic Marine is di...
#
#    popularity                               production_companies  ... runtime  \
# 0  150.437577  [{"name": "Ingenious Film Partners", "id": 289...  ...   162.0
#
#                                     spoken_languages    status  \
# 0  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
#
#                        tagline   title vote_average vote_count movie_id  \
# 0  Enter the World of Pandora.  Avatar          7.2      11800    19995
#
# ...

# %%
#Genre,
#id  #id for fetching posters
#keyword
#title
#overview
#runtime
#release Date
#cast
#crew
movies=movies[["title","id","genres","overview","keywords","runtime","cast","crew"]]

# %%
movies.head(2)
# Out:
#                                       title     id  \
# 0                                    Avatar  19995
# 1  Pirates of the Caribbean: At World's End    285
#
#                                               genres  \
# 0  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
#
#                                             keywords  runtime  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...    162.0
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...    169.0
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# ...

# %%
movies.isnull().sum()
# Out:
# title       0
# id          0
# genres      0
# overview    3
# keywords    0
# runtime     2
# cast        0
# crew        0
# dtype: int64

# %%
movies = movies.copy()
movies.dropna(inplace=True)

# %%
movies.isnull().sum()
# Out:
# title       0
# id          0
# genres      0
# overview    0
# keywords    0
# runtime     0
# cast        0
# crew        0
# dtype: int64

# %%
movies.duplicated().sum()   # checking duplicate data h ki nhii
# Out:
# 0

# %%
movie.iloc[0].genres
# Out:
# '[{"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}, {"id": 14, "name": "Fantasy"}, {"id": 878, "name": "Science Fiction"}]'

# %%
#'[{"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}, {"id": 14, "name": "Fantasy"}, {"id": 878, "name": "Science Fiction"}]'
#convert krna h iss form m...
#["action","adventure","fantasy","science-Fiction"]

# %%
##This is helper function
def convert(obj):
    l=[]
    for i in ast.literal_eval(obj):
        l.append(i["name"])
    return l

# %%
import ast
ast.literal_eval('[{"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}, {"id": 14, "name": "Fantasy"}, {"id": 878, "name": "Science Fiction"}]')
# Out:
# [{'id': 28, 'name': 'Action'},
#  {'id': 12, 'name': 'Adventure'},
#  {'id': 14, 'name': 'Fantasy'},
#  {'id': 878, 'name': 'Science Fiction'}]

# %%
convert('[{"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}, {"id": 14, "name": "Fantasy"}, {"id": 878, "name": "Science Fiction"}]')
# Out:
# ['Action', 'Adventure', 'Fantasy', 'Science Fiction']

# %%
movies["genres"]=movies["genres"].apply(convert)

# %%
movies.head()
# Out:
#                                       title      id  \
# 0                                    Avatar   19995
# 1  Pirates of the Caribbean: At World's End     285
# 2                                   Spectre  206647
# 3                     The Dark Knight Rises   49026
# 4                               John Carter   49529
#
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1                   [Adventure, Fantasy, Action]
# 2                     [Action, Adventure, Crime]
# 3               [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, Science Fiction]
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
# ...

# %%
movies["keywords"]=movies["keywords"].apply(convert)

# %%
movies.head(3)
# Out:
#                                       title      id  \
# 0                                    Avatar   19995
# 1  Pirates of the Caribbean: At World's End     285
# 2                                   Spectre  206647
#
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1                   [Adventure, Fantasy, Action]
# 2                     [Action, Adventure, Crime]
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
#
#                                             keywords  runtime  \
# 0  [culture clash, future, space war, space colon...    162.0
# 1  [ocean, drug abuse, exotic island, east india ...    169.0
# 2  [spy, based on novel, secret agent, sequel, mi...    148.0
#
#                                                 cast  \
# ...

# %%
movies["cast"][0]
# Out:
# '[{"cast_id": 242, "character": "Jake Sully", "credit_id": "5602a8a7c3a3685532001c9a", "gender": 2, "id": 65731, "name": "Sam Worthington", "order": 0}, {"cast_id": 3, "character": "Neytiri", "credit_id": "52fe48009251416c750ac9cb", "gender": 1, "id": 8691, "name": "Zoe Saldana", "order": 1}, {"cast_id": 25, "character": "Dr. Grace Augustine", "credit_id": "52fe48009251416c750aca39", "gender": 1, "id": 10205, "name": "Sigourney Weaver", "order": 2}, {"cast_id": 4, "character": "Col. Quaritch", "credit_id": "52fe48009251416c750ac9cf", "gender": 2, "id": 32747, "name": "Stephen Lang", "order": 3}, {"cast_id": 5, "character": "Trudy Chacon", "credit_id": "52fe48009251416c750ac9d3", "gender": 1, "id": 17647, "name": "Michelle Rodriguez", "order": 4}, {"cast_id": 8, "character": "Selfridge", "credit_id": "52fe48009251416c750ac9e1", "gender": 2, "id": 1771, "name": "Giovanni Ribisi", "order": 5}, {"cast_id": 7, "character": "Norm Spellman", "credit_id": "52fe48009251416c750ac9dd", "gender"
# ...

# %%
def convert3(obj):
    l=[]
    counter=0
    for i in ast.literal_eval(obj):
        if counter!=3:
            l.append(i["name"])
            counter+=1
        else:
            break
    return l

# %%
movies["cast"]=movies["cast"].apply(convert3)

# %%
movies
# Out:
#                                          title      id  \
# 0                                       Avatar   19995
# 1     Pirates of the Caribbean: At World's End     285
# 2                                      Spectre  206647
# 3                        The Dark Knight Rises   49026
# 4                                  John Carter   49529
# ...                                        ...     ...
# 4804                               El Mariachi    9367
# 4805                                 Newlyweds   72766
# 4806                 Signed, Sealed, Delivered  231617
# 4807                          Shanghai Calling  126186
# 4808                         My Date with Drew   25975
#
#                                              genres  \
# 0     [Action, Adventure, Fantasy, Science Fiction]
# 1                      [Adventure, Fantasy, Action]
# 2                        [Action, Adventure, Crime]
# 3                  [Action, Crime, Drama, Thriller]
# ...

# %%
def fetch_director(obj):
    l = []
    for i in ast.literal_eval(obj):
        if i["job"] == "Director":
            l.append(i["name"])
            break
    return l

# %%
movies["crew"]=movies["crew"].apply(fetch_director)

# %%
movies.head()
# Out:
#                                       title      id  \
# 0                                    Avatar   19995
# 1  Pirates of the Caribbean: At World's End     285
# 2                                   Spectre  206647
# 3                     The Dark Knight Rises   49026
# 4                               John Carter   49529
#
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1                   [Adventure, Fantasy, Action]
# 2                     [Action, Adventure, Crime]
# 3               [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, Science Fiction]
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
# ...

# %%
#here everything is converted in list now we are converting overview into list bcz it is a string:

# %%
movies["overview"][0]
# Out:
# 'In the 22nd century, a paraplegic Marine is dispatched to the moon Pandora on a unique mission, but becomes torn between following orders and protecting an alien civilization.'

# %%
movies["overview"]=movies["overview"].apply(lambda x:x.split())

# %%
movies.head()
# Out:
#                                       title      id  \
# 0                                    Avatar   19995
# 1  Pirates of the Caribbean: At World's End     285
# 2                                   Spectre  206647
# 3                     The Dark Knight Rises   49026
# 4                               John Carter   49529
#
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1                   [Adventure, Fantasy, Action]
# 2                     [Action, Adventure, Crime]
# 3               [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, Science Fiction]
#
#                                             overview  \
# 0  [In, the, 22nd, century,, a, paraplegic, Marin...
# 1  [Captain, Barbossa,, long, believed, to, be, d...
# 2  [A, cryptic, message, from, Bond’s, past, send...
# 3  [Following, the, death, of, District, Attorney...
# 4  [John, Carter, is, a, war-weary,, former, mili...
#
# ...

# %%
#here we are trying to remove space between names,genre and rest of things because many times we have got the same name thats why we merge full name

# %%
movies["genres"]=movies["genres"].apply(lambda x:[(i.replace(" ","")) for i in x])
movies["keywords"]=movies["keywords"].apply(lambda x:[(i.replace(" ","")) for i in x])
movies["cast"]=movies["cast"].apply(lambda x:[(i.replace(" ","")) for i in x])
movies["crew"]=movies["crew"].apply(lambda x:[(i.replace(" ","")) for i in x])

# %%
movies.head(3)
# Out:
#                                       title      id  \
# 0                                    Avatar   19995
# 1  Pirates of the Caribbean: At World's End     285
# 2                                   Spectre  206647
#
#                                          genres  \
# 0  [Action, Adventure, Fantasy, ScienceFiction]
# 1                  [Adventure, Fantasy, Action]
# 2                    [Action, Adventure, Crime]
#
#                                             overview  \
# 0  [In, the, 22nd, century,, a, paraplegic, Marin...
# 1  [Captain, Barbossa,, long, believed, to, be, d...
# 2  [A, cryptic, message, from, Bond’s, past, send...
#
#                                             keywords  runtime  \
# 0  [cultureclash, future, spacewar, spacecolony, ...    162.0
# 1  [ocean, drugabuse, exoticisland, eastindiatrad...    169.0
# 2  [spy, basedonnovel, secretagent, sequel, mi6, ...    148.0
#
#                                             cast             crew
# ...

# %% [markdown]
# ### lets create a new tag

# %%
movies["tags"]=movies["overview"] + movies["genres"] + movies["keywords"] + movies["cast"] + movies["crew"]

# %%
movies.head(5)
# Out:
#                                       title      id  \
# 0                                    Avatar   19995
# 1  Pirates of the Caribbean: At World's End     285
# 2                                   Spectre  206647
# 3                     The Dark Knight Rises   49026
# 4                               John Carter   49529
#
#                                          genres  \
# 0  [Action, Adventure, Fantasy, ScienceFiction]
# 1                  [Adventure, Fantasy, Action]
# 2                    [Action, Adventure, Crime]
# 3              [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, ScienceFiction]
#
#                                             overview  \
# 0  [In, the, 22nd, century,, a, paraplegic, Marin...
# 1  [Captain, Barbossa,, long, believed, to, be, d...
# 2  [A, cryptic, message, from, Bond’s, past, send...
# 3  [Following, the, death, of, District, Attorney...
# 4  [John, Carter, is, a, war-weary,, former, mili...
#
# ...

# %% [markdown]
# now we didnt have need for rest of colunms so we are gooing to create a new column

# %%
new_df=movies[["id","title","tags"]]

# %%
new_df
# Out:
#           id                                     title  \
# 0      19995                                    Avatar
# 1        285  Pirates of the Caribbean: At World's End
# 2     206647                                   Spectre
# 3      49026                     The Dark Knight Rises
# 4      49529                               John Carter
# ...      ...                                       ...
# 4804    9367                               El Mariachi
# 4805   72766                                 Newlyweds
# 4806  231617                 Signed, Sealed, Delivered
# 4807  126186                          Shanghai Calling
# 4808   25975                         My Date with Drew
#
#                                                    tags
# 0     [In, the, 22nd, century,, a, paraplegic, Marin...
# 1     [Captain, Barbossa,, long, believed, to, be, d...
# 2     [A, cryptic, message, from, Bond’s, past, send...
# 3     [Following, the, death, of, District, Attorney...
# ...

# %%
#Now we are again converting the list of tags into string

# %%
new_df["tags"]=new_df["tags"].apply(lambda x:" ".join(x))
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_32728\1804341217.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["tags"]=new_df["tags"].apply(lambda x:" ".join(x))

# %%
new_df.head()
# Out:
#        id                                     title  \
# 0   19995                                    Avatar
# 1     285  Pirates of the Caribbean: At World's End
# 2  206647                                   Spectre
# 3   49026                     The Dark Knight Rises
# 4   49529                               John Carter
#
#                                                 tags
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...

# %%
new_df["tags"][0]
# Out:
# 'In the 22nd century, a paraplegic Marine is dispatched to the moon Pandora on a unique mission, but becomes torn between following orders and protecting an alien civilization. Action Adventure Fantasy ScienceFiction cultureclash future spacewar spacecolony society spacetravel futuristic romance space alien tribe alienplanet cgi marine soldier battle loveaffair antiwar powerrelations mindandsoul 3d SamWorthington ZoeSaldana SigourneyWeaver JamesCameron'

# %%
#recommended to write tags in lower case:

# %%
new_df["tags"]=new_df["tags"].apply(lambda x:x.lower())
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_32728\4024514323.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["tags"]=new_df["tags"].apply(lambda x:x.lower())

# %%
new_df
# Out:
#           id                                     title  \
# 0      19995                                    Avatar
# 1        285  Pirates of the Caribbean: At World's End
# 2     206647                                   Spectre
# 3      49026                     The Dark Knight Rises
# 4      49529                               John Carter
# ...      ...                                       ...
# 4804    9367                               El Mariachi
# 4805   72766                                 Newlyweds
# 4806  231617                 Signed, Sealed, Delivered
# 4807  126186                          Shanghai Calling
# 4808   25975                         My Date with Drew
#
#                                                    tags
# 0     in the 22nd century, a paraplegic marine is di...
# 1     captain barbossa, long believed to be dead, ha...
# 2     a cryptic message from bond’s past sends him o...
# 3     following the death of district attorney harve...
# ...

# %% [markdown]
# # `Vectorization`

# %%
new_df["tags"][0]
# Out:
# 'in the 22nd century, a paraplegic marine is dispatched to the moon pandora on a unique mission, but becomes torn between following orders and protecting an alien civilization. action adventure fantasy sciencefiction cultureclash future spacewar spacecolony society spacetravel futuristic romance space alien tribe alienplanet cgi marine soldier battle loveaffair antiwar powerrelations mindandsoul 3d samworthington zoesaldana sigourneyweaver jamescameron'

# %%
new_df["tags"][1]
# Out:
# "captain barbossa, long believed to be dead, has come back to life and is headed to the edge of the earth with will turner and elizabeth swann. but nothing is quite as it seems. adventure fantasy action ocean drugabuse exoticisland eastindiatradingcompany loveofone'slife traitor shipwreck strongwoman ship alliance calypso afterlife fighter pirate swashbuckler aftercreditsstinger johnnydepp orlandobloom keiraknightley goreverbinski"

# %%
#Hume above dono tags m similarity dhundni hai!!

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv=CountVectorizer(max_features=5000,stop_words="english")

# %%
vectors=cv.fit_transform(new_df["tags"]).toarray()

# %%
cv.fit_transform(new_df["tags"]).toarray().shape
# Out:
# (4806, 5000)

# %%
vectors[0]
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
from sklearn.feature_extraction.text import CountVectorizer

# Initialize CountVectorizer
cv = CountVectorizer(max_features=5000, stop_words="english")

# Fit with some data
vectors=cv.fit_transform(new_df["tags"]).toarray()

# Use get_feature_names_out() instead of get_feature_names()
feature_names = cv.get_feature_names_out()
print(feature_names)
# Out:
# ['000' '007' '10' ... 'zone' 'zoo' 'zooeydeschanel']

# %%
print(len(feature_names))
# Out:
# 5000

# %%
#we are going to apply stemming 
#[loving][loved][love]--->[love[love][love]
#using nltk

# %%
pip install nltk
# Out:
# ...
#      ---------------------------------------- 0.0/41.5 kB ? eta -:--:--
#      --------- ------------------------------ 10.2/41.5 kB ? eta -:--:--
#      ------------------ ------------------- 20.5/41.5 kB 217.9 kB/s eta 0:00:01
#      ---------------------------- --------- 30.7/41.5 kB 262.6 kB/s eta 0:00:01
#      -------------------------------------  41.0/41.5 kB 245.8 kB/s eta 0:00:01
#      -------------------------------------- 41.5/41.5 kB 199.4 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#     --------------------------------------- 0.0/1.5 MB 660.6 kB/s eta 0:00:03
#    - -------------------------------------- 0.1/1.5 MB 656.4 kB/s eta 0:00:03
#    -- ------------------------------------- 0.1/1.5 MB 731.4 kB/s eta 0:00:02
#    ---- ----------------------------------- 0.2/1.5 MB 952.6 kB/s eta 0:00:02
#    ------- -------------------------------- 0.3/1.5 MB 1.1 MB/s eta 0:00:02
# ...

# %%
import nltk

# %%
from nltk.stem.porter import PorterStemmer

# Initialize PorterStemmer
ps = PorterStemmer()

# %%
def stem(text):
    y=[]
    for i in text.split():
        y.append(ps.stem(i))
    return " ".join(y)

# %%
new_df["tags"]=new_df["tags"].apply(stem)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_32728\1027202188.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["tags"]=new_df["tags"].apply(stem)

# %%
ps.stem("loving")
# Out:
# 'love'

# %%
stem()

# %%
#cosine distance according to angle we find similarity small angle similarity more else less similarity

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
similarity=cosine_similarity(vectors)

# %%
cosine_similarity(vectors).shape
# Out:
# (4806, 4806)

# %%
similarity[0]
# Out:
# array([1.        , 0.08346223, 0.0860309 , ..., 0.04499213, 0.        ,
#        0.        ])

# %% [markdown]
# # `Main Function`

# %%
sorted(list(enumerate(similarity[0])),reverse=True,key=lambda x:x[1])  # distances with index  # second no. ke basis pr sorting kr rahe h hum
# Out:
# [(0, 1.0000000000000002),
#  (1216, 0.28676966733820225),
#  (2409, 0.26901379342448517),
#  (3730, 0.2605130246476754),
#  (507, 0.255608593705383),
#  (539, 0.25038669783359574),
#  (582, 0.24511108480187255),
#  (1204, 0.24455799402225922),
#  (1194, 0.2367785320221084),
#  (61, 0.23179316248638276),
#  (778, 0.23174488732966075),
#  (4048, 0.2278389747471728),
#  (1920, 0.2252817784447915),
#  (2786, 0.21853668936906193),
#  (172, 0.21239769762143662),
#  (972, 0.2108663315950723),
#  (322, 0.2105263157894737),
#  (2333, 0.20443988269091456),
#  (3608, 0.20437977982832192),
#  (260, 0.20395079136182276),
#  (151, 0.2029530274475215),
#  (4192, 0.2029530274475215),
#  (1444, 0.20277677641345318),
#  (74, 0.2024645717996314),
#  (1089, 0.2020475485519274),
#  (3675, 0.1979082783981174),
#  (973, 0.19767387315371682),
#  (577, 0.1976738731537168),
#  (47, 0.19672236884115843),
#  (2971, 0.19252140716412977),
#  (942, 0.19134594929397597),
#  (495, 0.19088542889273336),
# ...

# %%
sorted(similarity[0],reverse=True) #here index positions lose
# Out:
# [1.0000000000000002,
#  0.28676966733820225,
#  0.26901379342448517,
#  0.2605130246476754,
#  0.255608593705383,
#  0.25038669783359574,
#  0.24511108480187255,
#  0.24455799402225922,
#  0.2367785320221084,
#  0.23179316248638276,
#  0.23174488732966075,
#  0.2278389747471728,
#  0.2252817784447915,
#  0.21853668936906193,
#  0.21239769762143662,
#  0.2108663315950723,
#  0.2105263157894737,
#  0.20443988269091456,
#  0.20437977982832192,
#  0.20395079136182276,
#  0.2029530274475215,
#  0.2029530274475215,
#  0.20277677641345318,
#  0.2024645717996314,
#  0.2020475485519274,
#  0.1979082783981174,
#  0.19767387315371682,
#  0.1976738731537168,
#  0.19672236884115843,
#  0.19252140716412977,
#  0.19134594929397597,
#  0.19088542889273336,
#  0.19088542889273336,
#  0.19007487139298027,
#  0.1892994097121204,
#  0.18731716231633883,
#  0.1873171623163388,
#  0.18693292157876878,
#  0.1860807318911967,
#  0.18394180184548975,
#  0.18394180184548975,
#  0.1813690625275029,
# ...

# %%
def recommend(movie):
    movie_index=new_df[new_df["title"]==movie].index[0]
    distance=similarity[movie_index ]
    movies_list=sorted(list(enumerate(distance)),reverse=True,key=lambda x:x[1])[1:6]  #Top 5 movies similarity
    for i in movies_list:
        print(new_df.iloc[i[0]].title)

# %%
recommend("Avatar")
# Out:
# Aliens vs Predator: Requiem
# Aliens
# Falcon Rising
# Independence Day
# Titan A.E.

# %%
new_df.iloc[1216].title
# Out:
# 'Aliens vs Predator: Requiem'

# %%
new_df[new_df["title"]=="Avatar"]
# Out:
#       id   title                                               tags
# 0  19995  Avatar  in the 22nd century, a parapleg marin is dispa...

# %%
new_df[new_df["title"]=="Avatar"].index[0]
# Out:
# 0

# %%
# dump movie to vs code

# %%
import pickle

# %%
pickle.dump(new_df,open("movies.pkl","wb"))

# %%
pickle.dump(similarity,open("similarity.pkl","wb"))
